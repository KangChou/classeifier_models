# %% [markdown]
# <a href="https://colab.research.google.com/github/KangChou/classeifier_models/blob/main/myappnlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 安装anaconda3
# !wget -c https://repo.continuum.io/archive/Anaconda3-2021.05-Linux-x86_64.sh
# !chmod +x Anaconda3-2021.05-Linux-x86_64.sh
# !bash ./Anaconda3-2021.05-Linux-x86_64.sh -bfp /usr/local
# !conda create --name py379 python=3.7.9
# !source activate py379
# Out:
# --2023-04-13 01:16:29--  https://repo.continuum.io/archive/Anaconda3-2021.05-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.201.79, 104.18.200.79, 2606:4700::6812:c84f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.201.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/archive/Anaconda3-2021.05-Linux-x86_64.sh [following]
# --2023-04-13 01:16:29--  https://repo.anaconda.com/archive/Anaconda3-2021.05-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 570853747 (544M) [application/x-sh]
# Saving to: ‘Anaconda3-2021.05-Linux-x86_64.sh’
#
# Anaconda3-2021.05-L 100%[===================>] 544.41M   293MB/s    in 1.9s
#
# ...

# %%
# !source activate py379
# !conda install tensorflow-gpu=2.3.2
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - tensorflow-gpu=2.3.2
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
# !source activate py379
import tensorflow as tf

# 检查是否连接到 GPU
if tf.test.gpu_device_name():
    print('GPU is connected.')
else:
    print('GPU is not connected.')

# 检查 TensorFlow 版本
print('TensorFlow version:', tf.__version__)
# Out:
# GPU is connected.
# TensorFlow version: 2.12.0

# %%
# !git clone https://github.com/percent4/transformers_chinese_text_classification.git
# Out:
# Cloning into 'transformers_chinese_text_classification'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 0), reused 15 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), 6.27 MiB | 9.64 MiB/s, done.

# %% [markdown]
# Hugging Face之中的bert-base-chinese模型文件，然后将模型文件保存到路径/content/transformers_chinese_text_classification/bert-base-chinese
#
# *   列表项
# *   列表项

# %%
! cd transformers_chinese_text_classification
# !ls
# !source activate py379


# # 配置开发环境
# !pip install -r requirements.txt
# Out:
# /bin/bash: line 0: cd: transformers_chinese_text_classification: No such file or directory
# Anaconda3-2021.05-Linux-x86_64.sh  model_predict.py  traindatasets_label.json
# bert-base-chinese		   model_train.py    util.py
# data				   README.md
# model_evaluate.py		   requirements.txt
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached tensorflow_gpu-2.3.2-cp38-cp38-manylinux2010_x86_64.whl (320.5 MB)
# ...
#   Using cached transformers-4.0.1-py3-none-any.whl (1.4 MB)
# ...
#   Using cached numpy-1.18.3-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# ...
#   Using cached pandas-0.23.0.tar.gz (13.1 MB)
# ...
#   Using cached scikit_learn-0.24.0-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
# ...
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached grpcio-1.53.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.0 MB)
# ...

# %%
# !source activate py379
import tensorflow as tf

# 检查是否连接到 GPU
if tf.test.gpu_device_name():
    print('GPU is connected.')
else:
    print('GPU is not connected.')

# 检查 TensorFlow 版本
print('TensorFlow version:', tf.__version__)
